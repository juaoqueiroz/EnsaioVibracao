# %%
import pandas as pd
from scipy.fft import fft, fftfreq
import numpy as np
import matplotlib.pyplot as plt

# %%
# Number of sample points
N = 600
# sample spacing
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N, endpoint=False)
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
yf = fft(y)
xf = fftfreq(N, T)[:N//2]
plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.show()

# %%
vibration_data = pd.read_csv("../Datasets/dataset_teste.csv", sep=';') #importando o arquivo
dt  = 3.906250E-5 #tempo entre amostras
N  = len(vibration_data['t']) #numero de amostras 
vibracao = vibration_data['vibracao']
yf = scipy.fft.fft(vibracao.values)
xf = fftfreq(N, dt)[:N//2]
plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.show()

# %%
import pandas as pd
import numpy as np
from numpy.fft import fft

# Importando o arquivo CSV
vibration_data = pd.read_csv("../Datasets/dataset_teste.csv", sep=';')

# Tempo entre amostras
dt = 3.906250E-5 

# Número de amostras
N = len(vibration_data['t'])

# Transformada Rápida de Fourier (FFT)
yf = fft(vibration_data['vibracao'])
